# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.loadtxt("history.txt")
plt.hist(data, bins=np.arange(-773.5,-766.4))
plt.show()

# %% [markdown]
# Гистограмма распределения по найденной энергии для 500 прогонов. Выполнялось с помощью скрипта на сервере

# %%
data500 = np.loadtxt("history_500.txt")
plt.hist(data500, bins=np.arange(-775.5,-766.4))
plt.show()
